# %%
import requests
import json
import chess.pgn
import io
import pandas as pd
import math
import numpy as np

# %%
pip install chess
# Out:
# ...
#   Obtaining dependency information for chess from https://files.pythonhosted.org/packages/d6/d8/15cfcb738d2518daf04d34b23419bd359cbd8e09da50778ebac521774fc8/chess-1.10.0-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 7.8 MB/s eta 0:00:00 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json

def get_data_by_month(username, year, month):
    url = f"https://api.chess.com/pub/player/{username}/games/{year}/{month:02d}"
    
    data = requests.get(url)
    if data.status_code != 200:
        raise Exception("The following response was returned: " + str(data.status_code))
    else:
        data = json.loads(data.text)
        games = data["games"]
        return games
# Out:
#   Cell In[4], line 3
#     url = f"https://api.chess.com/pub/player/jyan_500/games/2024/05"
#     ^
# IndentationError: expected an indented block after function definition on line 1

# %%
def get_data_by_month(username, year, month):
    url = f"https://api.chess.com/pub/player/{username}/games/{year}/{month}"
    data = requests.get(url)
    if data.status_code != 200:
        raise Exception("The following response was returned: " + str(data.status_code))
    else:
        data = json.loads(data.text)
        games = data["games"]
    
all_games=[]
for game in games:
    pgn = (game['pgn'])
    pgn = io.StringIO(pgn)
    game = chess.pgn.read_game(pgn)
    all_games.append(game)
    
game_list = []
    for g in all_games:
        moves = (g.mainline_moves())
        moves = [str(x) for x in moves]
        
        white = (g.headers['White'])
        if white.lower() == username.lower():
            playing_as_white = 1
        else:
            playing_as_white = 0
        
        if len(moves)>1:
            move_made = (moves[1])
        else:
            move_made = ""
        
        game = {"date": (g.headers["Date"]), "player_white": white, "player_black": (g.headers['Black']), "playing_as_white" : playing_as_white, "result": (g.headers['Result']), "termination": (g.headers['Termination']), "moves": moves, "no_of_moves": (math.ceil(len(moves)/2)), "first_move": (moves[0]), "response": move_made}
    
        
        game_list.append(game)
    game_list = pd.DataFrame(game_list)
    return game_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 11
#       8         games = data["games"]
#      10 all_games=[]
# ---> 11 for game in games:
#      12     pgn = (game['pgn'])
#      13     pgn = io.StringIO(pgn)
#
# NameError: name 'games' is not defined

# %%
import requests
import json
import io
import chess.pgn
import pandas as pd
import math

def get_data_by_month(username, year, month):
    url = f"https://api.chess.com/pub/player/{username}/games/{year}/{month:02d}"
    response = requests.get(url)
    
    if response.status_code != 200:
        raise Exception("The following response was returned: " + str(response.status_code))
    
    data = json.loads(response.text)
    games = data["games"]
    
    all_games = []
    for game in games:
        pgn = game['pgn']
        pgn = io.StringIO(pgn)
        game = chess.pgn.read_game(pgn)
        all_games.append(game)
    
    game_list = []
    for g in all_games:
        moves = g.mainline_moves()
        moves = [str(x) for x in moves]
        
        white = g.headers['White']
        if white.lower() == username.lower():
            playing_as_white = 1
        else:
            playing_as_white = 0
        
        if len(moves) > 1:
            move_made = moves[1]
        else:
            move_made = ""
        
        game_info = {
            "date": g.headers["Date"],
            "player_white": white,
            "player_black": g.headers['Black'],
            "playing_as_white": playing_as_white,
            "result": g.headers['Result'],
            "termination": g.headers['Termination'],
            "moves": moves,
            "no_of_moves": math.ceil(len(moves) / 2),
            "first_move": moves[0],
            "response": move_made
        }
        
        game_list.append(game_info)
    
    game_list_df = pd.DataFrame(game_list)
    return game_list_df

# Example usage
username = "jyan_500"
year = 2024
month = 5
games_df = get_data_by_month(username, year, month)
print(games_df)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[12], line 63
#      61 year = 2024
#      62 month = 5
# ---> 63 games_df = get_data_by_month(username, year, month)
#      64 print(games_df)
#
# Cell In[12], line 13, in get_data_by_month(username, year, month)
#      10 response = requests.get(url)
#      12 if response.status_code != 200:
# ---> 13     raise Exception("The following response was returned: " + str(response.status_code))
#      15 data = json.loads(response.text)
#      16 games = data["games"]
#
# Exception: The following response was returned: 403

# %%
import requests
import json
import io
import chess.pgn
import pandas as pd
import math

def get_data_by_month(username, year, month):
    url = f"https://api.chess.com/pub/player/{username}/games/{year}/{month:02d}"
    response = requests.get(url)
    
    if response.status_code != 200:
        print("Response Content:", response.text)  # Print detailed response
        raise Exception("The following response was returned: " + str(response.status_code))
    
    data = json.loads(response.text)
    games = data["games"]
    
    all_games = []
    for game in games:
        pgn = game['pgn']
        pgn = io.StringIO(pgn)
        game = chess.pgn.read_game(pgn)
        all_games.append(game)
    
    game_list = []
    for g in all_games:
        moves = g.mainline_moves()
        moves = [str(x) for x in moves]
        
        white = g.headers['White']
        if white.lower() == username.lower():
            playing_as_white = 1
        else:
            playing_as_white = 0
        
        if len(moves) > 1:
            move_made = moves[1]
        else:
            move_made = ""
        
        game_info = {
            "date": g.headers["Date"],
            "player_white": white,
            "player_black": g.headers['Black'],
            "playing_as_white": playing_as_white,
            "result": g.headers['Result'],
            "termination": g.headers['Termination'],
            "moves": moves,
            "no_of_moves": math.ceil(len(moves) / 2),
            "first_move": moves[0],
            "response": move_made
        }
        
        game_list.append(game_info)
    
    game_list_df = pd.DataFrame(game_list)
    return game_list_df

# Example usage
username = "jyan_500"
year = 2024
month = 5
try:
    games_df = get_data_by_month(username, year, month)
    print(games_df)
except Exception as e:
    print(e)
# Out:
# Response Content: <!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131}button,html{font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}body a{color:#fff}body a:hover{color:#ee730a;text-decoration:underline}body .lds-ring div{border-color:#999 transparent transparent}body .font-red{color:#b20f03}body .pow-button{background-color:#4693ff;color:#1d1d1d}body #challenge-success-text{background-image:url(data:image/svg+xml;base64
# ...

# %%
import json
import pandas as pd

# Sample JSON data
json_data = '''
{
    "games": [
        {
            "url": "https://www.chess.com/game/daily/644030175",
            "pgn": "[Event \"Let's Play!\"]",
            "time_control": "1/86400",
            "end_time": 1714610273,
            "rated": false,
            "tcn": "mCYIbs0SfAZJCJSJAJ!Tdm90mv8?ltTJsJ0Rgm5QcD98eh6Sms46feQBvdRDJDSLac7Me868sJ3VksBQdlL3ce8ele!9euMLuCLCtC3CJYWOnvCLoEL6pFQKgoXHon6XYJXJDJKtnutjJYjAuDARYORXOYHzszIzYJzrirXRDKRHrz98vD8ZDL1TJT2TKTHREMR8TUVMFMZ0zH8RHPRXU2X7LT0SPX7XT1XR1~RL23SK9TKDMUDEU2L2T2EN2UNF3VFxVNxpUEphNMhpMDphDvhpEo",
            "uuid": "1cef1292-f681-11ee-8ea8-30e1f301000b",
            "initial_setup": "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1",
            "fen": "8/8/8/8/8/5K2/6Qk/8 b - - 16 71",
            "start_time": 1712674489,
            "time_class": "daily",
            "rules": "chess",
            "white": {
                "rating": 1323,
                "result": "win",
                "@id": "https://api.chess.com/pub/player/aaronsmatta",
                "username": "aaronSmatta",
                "uuid": "2a0ff9aa-b37d-11ea-bdd5-756c1c59b54e"
            }
        }
    ]
}
'''

# Load JSON data
data = json.loads(json_data)

# Extract relevant fields
games = data["games"]

# Initialize a list to hold game data
game_list = []

# Loop through each game and extract the fields
for game in games:
    game_info = {
        "url": game["url"],
        "pgn": game["pgn"],
        "time_control": game["time_control"],
        "end_time": game["end_time"],
        "rated": game["rated"],
        "uuid": game["uuid"],
        "initial_setup": game["initial_setup"],
        "fen": game["fen"],
        "start_time": game["start_time"],
        "time_class": game["time_class"],
        "rules": game["rules"],
        "white_rating": game["white"]["rating"],
        "white_result": game["white"]["result"],
        "white_id": game["white"]["@id"],
        "white_username": game["white"]["username"],
        "white_uuid": game["white"]["uuid"]
    }
    game_list.append(game_info)

# Create a DataFrame from the list
games_df = pd.DataFrame(game_list)

# Display the DataFrame
print(games_df)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[14], line 34
#       5 json_data = '''
#       6 {
#       7     "games": [
#    (...)
#      30 }
#      31 '''
#      33 # Load JSON data
# ---> 34 data = json.loads(json_data)
#      36 # Extract relevant fields
#      37 games = data["games"]
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import json
import pandas as pd

# Corrected JSON data
json_data = '''
{
    "games": [
        {
            "url": "https://www.chess.com/game/daily/644030175",
            "pgn": "[Event \\"Let's Play!\\"]",
            "time_control": "1/86400",
            "end_time": 1714610273,
            "rated": false,
            "tcn": "mCYIbs0SfAZJCJSJAJ!Tdm90mv8?ltTJsJ0Rgm5QcD98eh6Sms46feQBvdRDJDSLac7Me868sJ3VksBQdlL3ce8ele!9euMLuCLCtC3CJYWOnvCLoEL6pFQKgoXHon6XYJXJDJKtnutjJYjAuDARYORXOYHzszIzYJzrirXRDKRHrz98vD8ZDL1TJT2TKTHREMR8TUVMFMZ0zH8RHPRXU2X7LT0SPX7XT1XR1~RL23SK9TKDMUDEU2L2T2EN2UNF3VFxVNxpUEphNMhpMDphDvhpEo",
            "uuid": "1cef1292-f681-11ee-8ea8-30e1f301000b",
            "initial_setup": "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1",
            "fen": "8/8/8/8/8/5K2/6Qk/8 b - - 16 71",
            "start_time": 1712674489,
            "time_class": "daily",
            "rules": "chess",
            "white": {
                "rating": 1323,
                "result": "win",
                "@id": "https://api.chess.com/pub/player/aaronsmatta",
                "username": "aaronSmatta",
                "uuid": "2a0ff9aa-b37d-11ea-bdd5-756c1c59b54e"
            }
        }
    ]
}
'''

# Load JSON data
data = json.loads(json_data)

# Extract relevant fields
games = data["games"]

# Initialize a list to hold game data
game_list = []

# Loop through each game and extract the fields
for game in games:
    game_info = {
        "url": game["url"],
        "pgn": game["pgn"],
        "time_control": game["time_control"],
        "end_time": game["end_time"],
        "rated": game["rated"],
        "uuid": game["uuid"],
        "initial_setup": game["initial_setup"],
        "fen": game["fen"],
        "start_time": game["start_time"],
        "time_class": game["time_class"],
        "rules": game["rules"],
        "white_rating": game["white"]["rating"],
        "white_result": game["white"]["result"],
        "white_id": game["white"]["@id"],
        "white_username": game["white"]["username"],
        "white_uuid": game["white"]["uuid"]
    }
    game_list.append(game_info)

# Create a DataFrame from the list
games_df = pd.DataFrame(game_list)

# Display the DataFrame
print(games_df)
# Out:
#                                           url                    pgn  \
# 0  https://www.chess.com/game/daily/644030175  [Event "Let's Play!"]
#
#   time_control    end_time  rated                                  uuid  \
# 0      1/86400  1714610273  False  1cef1292-f681-11ee-8ea8-30e1f301000b
#
#                                        initial_setup  \
# 0  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
#
#                                fen  start_time time_class  rules  \
# 0  8/8/8/8/8/5K2/6Qk/8 b - - 16 71  1712674489      daily  chess
#
#    white_rating white_result                                      white_id  \
# 0          1323          win  https://api.chess.com/pub/player/aaronsmatta
#
#   white_username                            white_uuid
# 0    aaronSmatta  2a0ff9aa-b37d-11ea-bdd5-756c1c59b54e

# %%
games_df
# Out:
#                                           url                    pgn  \
# 0  https://www.chess.com/game/daily/644030175  [Event "Let's Play!"]
#
#   time_control    end_time  rated                                  uuid  \
# 0      1/86400  1714610273  False  1cef1292-f681-11ee-8ea8-30e1f301000b
#
#                                        initial_setup  \
# 0  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
#
#                                fen  start_time time_class  rules  \
# 0  8/8/8/8/8/5K2/6Qk/8 b - - 16 71  1712674489      daily  chess
#
#    white_rating white_result                                      white_id  \
# 0          1323          win  https://api.chess.com/pub/player/aaronsmatta
#
#   white_username                            white_uuid
# 0    aaronSmatta  2a0ff9aa-b37d-11ea-bdd5-756c1c59b54e

# %%
import json
import pandas as pd

# Corrected JSON data
json_data = '''
{
    "games": [
        {
            "url": "https://www.chess.com/game/daily/644030175",
            "pgn": "[Event \"Let's Play!\"]\n[Site \"Chess.com\"]\n[Date \"2024.04.09\"]\n[Round \"-\"]\n[White \"aaronSmatta\"]\n[Black \"jyan_500\"]\n[Result \"1-0\"]\n[CurrentPosition \"8/8/8/8/8/5K2/6Qk/8 b - - 16 71\"]\n[Timezone \"UTC\"]\n[ECO \"B23\"]\n[ECOUrl \"https://www.chess.com/openings/Closed-Sicilian-Defense-2...e6\"]\n[UTCDate \"2024.04.09\"]\n[UTCTime \"14:54:49\"]\n[WhiteElo \"1323\"]\n[BlackElo \"1162\"]\n[TimeControl \"1/86400\"]\n[Termination \"aaronSmatta won by checkmate\"]\n[StartTime \"14:54:49\"]\n[EndDate \"2024.05.02\"]\n[EndTime \"00:37:53\"]\n[Link \"https://www.chess.com/game/daily/644030175\"]\n\n1. e4 {[%clk 23:59:56]} 1... c5 {[%clk 17:27:30]} 2. Nc3 {[%clk 21:03:33]} 2... e6 {[%clk 18:12:23]} 3. Bc4 {[%clk 15:36:17]} 3... d5 {[%clk 15:08:25]} 4. exd5 {[%clk 23:36:22]} 4... exd5 {[%clk 19:39:42]} 5. Bxd5 {[%clk 23:01:32]} 5... Nf6 {[%clk 22:11:40]} 6. Qe2+ {[%clk 16:29:10]} 6... Be7 {[%clk 21:58:38]} 7. Qf3 {[%clk 23:13:37]} 7... O-O {[%clk 13:52:37]} 8. d3 {[%clk 23:11:19]} 8... Nxd5 {[%clk 23:59:24]} 9. Nxd5 {[%clk 23:58:53]} 9... Bd6 {[%clk 8:55:36]} 10. Ne2 {[%clk 23:58:27]} 10... Nc6 {[%clk 2:33:47]} 11. Bf4 {[%clk 22:43:08]} 11... Re8 {[%clk 1:39:00]} 12. O-O {[%clk 20:11:57]} 12... Be6 {[%clk 20:03:41]} 13. Nec3 {[%clk 21:28:23]} 13... Rc8 {[%clk 21:49:30]} 14. Rfe1 {[%clk 23:16:24]} 14... Nd4 {[%clk 10:39:19]} 15. Qd1 {[%clk 19:45:43]} 15... Bxf4 {[%clk 20:57:32]
 0:00:55.7]} 37... g4 {[%clk 0:02:23.3]} 38. Ra2+ {[%clk 0:00:54.2]} 38... Kb7 {[%clk 0:02:21.9]} 39. b5 {[%clk 0:00:42.8]} 39... Rc5 {[%clk 0:02:18.1]} 40. Re4 {[%clk 0:00:40.9]} 40... c6 {[%clk 0:02:01.5]} 41. bxc6+ {[%clk 0:00:39]} 41... Kxc6 {[%clk 0:02:00.9]} 42. Rd2 {[%clk 0:00:36.7]} 42... b5 {[%clk 0:01:55.3]} 43. cxb5+ {[%clk 0:00:34.4]} 43... Kxb5 {[%clk 0:01:54.3]} 44. Rdd4 {[%clk 0:00:33.7]} 44... Rc2+ {[%clk 0:01:47.9]} 45. Kf1 {[%clk 0:00:30.2]} 45... Rh7 {[%clk 0:01:35.5]} 46. Re5+ {[%clk 0:00:19.5]} 46... Kc6 {[%clk 0:01:33.1]} 47. Re6+ {[%clk 0:00:15]} 47... Kc5 {[%clk 0:01:31.6]} 0-1\n",
            "time_control": "300",
            "end_time": 1717220445,
            "rated": true,
            "accuracies": {
                "white": 78.82,
                "black": 83.09
            },
            "tcn": "mC0Kgv!TbsZJCJTJsJ7Jlt6Efm5QegKCtCJCfe90cuEZmtCEdm86ad3NpxESvM0MuM1TmSZSeSTMdeMEtLQBSKBLKL2ULT?!xENETS!2owXPgo7lemlJnvEvovWGiqJLvo6XksXOjzGzqzUMsAMEmiOXzHLISCYQHQXQilPHAHQHlBIkof23CKHQKSQI",
            "uuid": "43d00d5f-1fd8-11ef-8acd-6cfe544c0428",
            "initial_setup": "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1",
            "fen": "8/7r/4R3/2k5/3R2p1/6P1/2r5/5K2 w - -",
            "time_class": "blitz",
            "rules": "chess",
            "white": {
                "rating": 1410,
                "result": "timeout",
                "@id": "https://api.chess.com/pub/player/jyan_500",
                "username": "jyan_500",
                "uuid": "df2699c2-c63c-11e4-8000-000000000000"
            },
            "black": {
                "rating": 1422,
                "result": "win",
                "@id": "https://api.chess.com/pub/player/vlobo88",
                "username": "vlobo88",
                "uuid": "b3658a9c-b25f-11ed-837f-0fafe7c86ec0"
            }
        }
    ]
}
'''

# Load JSON data
data = json.loads(json_data)

# Extract relevant fields
games = data["games"]

# Initialize a list to hold game data
game_list = []

# Loop through each game and extract the fields
for game in games:
    game_info = {
        "url": game["url"],
        "pgn": game["pgn"],
        "time_control": game["time_control"],
        "end_time": game["end_time"],
        "rated": game["rated"],
        "uuid": game["uuid"],
        "initial_setup": game["initial_setup"],
        "fen": game["fen"],
        "start_time": game["start_time"],
        "time_class": game["time_class"],
        "rules": game["rules"],
        "white_rating": game["white"]["rating"],
        "white_result": game["white"]["result"],
        "white_id": game["white"]["@id"],
        "white_username": game["white"]["username"],
        "white_uuid": game["white"]["uuid"]
    }
    game_list.append(game_info)

# Create a DataFrame from the list
games_df = pd.DataFrame(game_list)

# Display the DataFrame
print(games_df)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[17], line 443
#       5 json_data = '''
#       6 {
#       7     "games": [
#    (...)
#     439 }
#     440 '''
#     442 # Load JSON data
# --> 443 data = json.loads(json_data)
#     445 # Extract relevant fields
#     446 games = data["games"]
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
import pandas as pd

# Sample JSON data as a string
json_data = '''
{
    "games": [
        {
            "url": "https://www.chess.com/game/daily/644030175",
            "pgn": "[Event \\"Let's Play!\\"]",
            "time_control": "1/86400",
            "end_time": 1714610273,
            "rated": false,
            "uuid": "1cef1292-f681-11ee-8ea8-30e1f301000b",
            "initial_setup": "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1",
            "fen": "8/8/8/8/8/5K2/6Qk/8 b - - 16 71",
            "start_time": 1712674489,
            "time_class": "daily",
            "rules": "chess",
            "white": {
                "rating": 1323,
                "result": "win",
                "@id": "https://api.chess.com/pub/player/aaronsmatta",
                "username": "aaronSmatta",
                "uuid": "2a0ff9aa-b37d-11ea-bdd5-756c1c59b54e"
            }
        }
    ]
}
'''

# Convert JSON string to DataFrame
df = pd.read_json(json_data)

# Display the DataFrame
print(df)
# Out:
#                                                games
# 0  {'url': 'https://www.chess.com/game/daily/6440...

# %%
df
# Out:
#                                                games
# 0  {'url': 'https://www.chess.com/game/daily/6440...

# %%
import pandas as pd
import json
from pandas import json_normalize

# Sample JSON data as a string
json_data = '''
{
    "games": [
        {
            "url": "https://www.chess.com/game/daily/644030175",
            "pgn": "[Event \"Let's Play!\"]\n[Site \"Chess.com\"]\n[Date \"2024.04.09\"]\n[Round \"-\"]\n[White \"aaronSmatta\"]\n[Black \"jyan_500\"]\n[Result \"1-0\"]\n[CurrentPosition \"8/8/8/8/8/5K2/6Qk/8 b - - 16 71\"]\n[Timezone \"UTC\"]\n[ECO \"B23\"]\n[ECOUrl \"https://www.chess.com/openings/Closed-Sicilian-Defense-2...e6\"]\n[UTCDate \"2024.04.09\"]\n[UTCTime \"14:54:49\"]\n[WhiteElo \"1323\"]\n[BlackElo \"1162\"]\n[TimeControl \"1/86400\"]\n[Termination \"aaronSmatta won by checkmate\"]\n[StartTime \"14:54:49\"]\n[EndDate \"2024.05.02\"]\n[EndTime \"00:37:53\"]\n[Link \"https://www.chess.com/game/daily/644030175\"]\n\n1. e4 {[%clk 23:59:56]} 1... c5 {[%clk 17:27:30]} 2. Nc3 {[%clk 21:03:33]} 2... e6 {[%clk 18:12:23]} 3. Bc4 {[%clk 15:36:17]} 3... d5 {[%clk 15:08:25]} 4. exd5 {[%clk 23:36:22]} 4... exd5 {[%clk 19:39:42]} 5. Bxd5 {[%clk 23:01:32]} 5... Nf6 {[%clk 22:11:40]} 6. Qe2+ {[%clk 16:29:10]} 6... Be7 {[%clk 21:58:38]} 7. Qf3 {[%clk 23:13:37]} 7... O-O {[%clk 13:52:37]} 8. d3 {[%clk 23:11:19]} 8... Nxd5 {[%clk 23:59:24]} 9. Nxd5 {[%clk 23:58:53]} 9... Bd6 {[%clk 8:55:36]} 10. Ne2 {[%clk 23:58:27]} 10... Nc6 {[%clk 2:33:47]} 11. Bf4 {[%clk 22:43:08]} 11... Re8 {[%clk 1:39:00]} 12. O-O {[%clk 20:11:57]} 12... Be6 {[%clk 20:03:41]} 13. Nec3 {[%clk 21:28:23]} 13... Rc8 {[%clk 21:49:30]} 14. Rfe1 {[%clk 23:16:24]} 14... Nd4 {[%clk 10:39:19]} 15. Qd1 {[%clk 19:45:43]} 15... Bxf4 {[%clk 20:57:32]} 16. Nxf4 {[%clk 23:59:33]} 16... Bf5 {[%clk 23:42:33]} 17. Rc1 {[%clk 23:34:16]} 17... Qg5 {[%clk 19:41:27]} 18. Rxe8+ {[%clk 14:59:49]} 18... Rxe8 {[%clk 20:00:53]} 19. Ncd5 {[%clk 23:08:50]} 19... h6 {[%clk 22:16:28]} 20. c3 {[%clk 20:40:30]} 20... Nc6 {[%clk 22:11:40]} 21. Qd2 {[%clk 23:46:47]} 21... Bh7 {[%clk 1:19:23]} 22. Re1
:02:32.5]} 35. b4 {[%clk 0:01:04]} 35... axb4 {[%clk 0:02:30.9]} 36. axb4 {[%clk 0:00:59.6]} 36... g5 {[%clk 0:02:27.5]} 37. c4 {[%clk 0:00:55.7]} 37... g4 {[%clk 0:02:23.3]} 38. Ra2+ {[%clk 0:00:54.2]} 38... Kb7 {[%clk 0:02:21.9]} 39. b5 {[%clk 0:00:42.8]} 39... Rc5 {[%clk 0:02:18.1]} 40. Re4 {[%clk 0:00:40.9]} 40... c6 {[%clk 0:02:01.5]} 41. bxc6+ {[%clk 0:00:39]} 41... Kxc6 {[%clk 0:02:00.9]} 42. Rd2 {[%clk 0:00:36.7]} 42... b5 {[%clk 0:01:55.3]} 43. cxb5+ {[%clk 0:00:34.4]} 43... Kxb5 {[%clk 0:01:54.3]} 44. Rdd4 {[%clk 0:00:33.7]} 44... Rc2+ {[%clk 0:01:47.9]} 45. Kf1 {[%clk 0:00:30.2]} 45... Rh7 {[%clk 0:01:35.5]} 46. Re5+ {[%clk 0:00:19.5]} 46... Kc6 {[%clk 0:01:33.1]} 47. Re6+ {[%clk 0:00:15]} 47... Kc5 {[%clk 0:01:31.6]} 0-1\n",
            "time_control": "300",
            "end_time": 1717220445,
            "rated": true,
            "accuracies": {
                "white": 78.82,
                "black": 83.09
            },
            "tcn": "mC0Kgv!TbsZJCJTJsJ7Jlt6Efm5QegKCtCJCfe90cuEZmtCEdm86ad3NpxESvM0MuM1TmSZSeSTMdeMEtLQBSKBLKL2ULT?!xENETS!2owXPgo7lemlJnvEvovWGiqJLvo6XksXOjzGzqzUMsAMEmiOXzHLISCYQHQXQilPHAHQHlBIkof23CKHQKSQI",
            "uuid": "43d00d5f-1fd8-11ef-8acd-6cfe544c0428",
            "initial_setup": "rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w KQkq - 0 1",
            "fen": "8/7r/4R3/2k5/3R2p1/6P1/2r5/5K2 w - -",
            "time_class": "blitz",
            "rules": "chess",
            "white": {
                "rating": 1410,
                "result": "timeout",
                "@id": "https://api.chess.com/pub/player/jyan_500",
                "username": "jyan_500",
                "uuid": "df2699c2-c63c-11e4-8000-000000000000"
            },
            "black": {
                "rating": 1422,
                "result": "win",
                "@id": "https://api.chess.com/pub/player/vlobo88",
                "username": "vlobo88",
                "uuid": "b3658a9c-b25f-11ed-837f-0fafe7c86ec0"
            }
        }
    ]
}
'''

# Load JSON data into a Python dictionary
data = json.loads(json_data)

# Normalize the data
df = json_normalize(data['games'])

# Display the DataFrame
print(df)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[23], line 444
#       6 json_data = '''
#       7 {
#       8     "games": [
#    (...)
#     440 }
#     441 '''
#     443 # Load JSON data into a Python dictionary
# --> 444 data = json.loads(json_data)
#     446 # Normalize the data
#     447 df = json_normalize(data['games'])
#
# File ~/anaconda3/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
df
# Out:
#                                           url                    pgn  \
# 0  https://www.chess.com/game/daily/644030175  [Event "Let's Play!"]
#
#   time_control    end_time  rated                                  uuid  \
# 0      1/86400  1714610273  False  1cef1292-f681-11ee-8ea8-30e1f301000b
#
#                                        initial_setup  \
# 0  rnbqkbnr/pppppppp/8/8/8/8/PPPPPPPP/RNBQKBNR w ...
#
#                                fen  start_time time_class  rules  \
# 0  8/8/8/8/8/5K2/6Qk/8 b - - 16 71  1712674489      daily  chess
#
#    white.rating white.result                                     white.@id  \
# 0          1323          win  https://api.chess.com/pub/player/aaronsmatta
#
#   white.username                            white.uuid
# 0    aaronSmatta  2a0ff9aa-b37d-11ea-bdd5-756c1c59b54e

# %%
import pandas as pd

# Load JSON data
json_path = 'json_1.json'
df = pd.read_json(json_path)

# Display the DataFrame
df.head()
# Out:
#                                                games
# 0  {'url': 'https://www.chess.com/game/daily/6440...
# 1  {'url': 'https://www.chess.com/game/live/10879...
# 2  {'url': 'https://www.chess.com/game/live/10905...
# 3  {'url': 'https://www.chess.com/game/daily/6525...
# 4  {'url': 'https://www.chess.com/game/live/10914...

# %%
import pandas as pd
import json

# Open JSON file
with open('json_1.json', 'r') as file:
    data = json.load(file)

# Normalize the data
from pandas import json_normalize
normalized_df = json_normalize(data['games'])  # Adjust 'games' to your actual key

# Display the DataFrame
print(normalized_df.head())
# Out:
#                                             url  \
# 0    https://www.chess.com/game/daily/644030175
# 1  https://www.chess.com/game/live/108792604287
# 2  https://www.chess.com/game/live/109054173603
# 3    https://www.chess.com/game/daily/652513337
# 4  https://www.chess.com/game/live/109143667273
#
#                                                  pgn time_control    end_time  \
# 0  [Event "Let's Play!"]\n[Site "Chess.com"]\n[Da...      1/86400  1714610273
# 1  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        300+5  1715054634
# 2  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        300+5  1715316136
# 3  [Event "Let's Play!"]\n[Site "Chess.com"]\n[Da...      1/86400  1715373593
# 4  [Event "Live Chess"]\n[Site "Chess.com"]\n[Dat...        300+5  1715405134
#
#    rated                                                tcn  \
# 0  False  mCYIbs0SfAZJCJSJAJ!Tdm90mv8?ltTJsJ0Rgm5QcD98eh...
# 1   True  mC0Kbs!TfAZRlt3VnDWOgvXHAr6EegYQcuOGiq90pxEZDK...
# ...

# %%
normalized_df.to_csv('chess.csv', index=False)

# %%
import pandas as with open

# Example DataFrame
df = pd.DataFrame({
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'Occupation': ['Engineer', 'Doctor', 'Artist']
})

# Save the DataFrame to a CSV file
csv_file_path = 'my_dataframe.csv'
df.to_csv(csv_file_path, index=False)  # Set 'index=False' to exclude row indices in the output file
# Out:
#                                              url  \
# 0     https://www.chess.com/game/daily/644030175
# 1   https://www.chess.com/game/live/108792604287
# 2   https://www.chess.com/game/live/109054173603
# 3     https://www.chess.com/game/daily/652513337
# 4   https://www.chess.com/game/live/109143667273
# 5   https://www.chess.com/game/live/109144207851
# 6   https://www.chess.com/game/live/109144240675
# 7   https://www.chess.com/game/live/109399257619
# 8   https://www.chess.com/game/live/109400434767
# 9     https://www.chess.com/game/daily/650183399
# 10  https://www.chess.com/game/live/109487461119
# 11    https://www.chess.com/game/daily/655735569
# 12    https://www.chess.com/game/daily/644573003
# 13  https://www.chess.com/game/live/110580174949
# 14  https://www.chess.com/game/live/110958670209
#
#                                                   pgn time_control  \
# 0   [Event "Let's Play!"]\n[Site "Chess.com"]\n[Da...      1/86400
# ...

# %%
pip install python-chess
# Out:
# ...
#   Obtaining dependency information for python-chess from https://files.pythonhosted.org/packages/38/47/dfebc06e589530691d33c71bc7b3d8d311252b58ae338980fd4327fe77f2/python_chess-1.999-py3-none-any.whl.metadata
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import chess.pgn
import io

# Sample DataFrame
data = {
    'pgn': [
        "1. d4 e6 2. Bf4 d5 3. Nf3 Bd6 4. g3 Nf6"
    ]
}

df = pd.DataFrame(data)

# Read the PGN string from the first cell of the 'pgn' column
pgn_string = df.loc[0, 'pgn']
print("PGN String:", pgn_string)

# Define an openings database
openings = {
    "Queen's Pawn Game": ["d4", "e6", "Bf4", "d5", "Nf3", "Bd6", "g3", "Nf6"],
    # Add more openings as needed
}

# Function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Extract the moves
moves = extract_moves_from_pgn(pgn_string)
print("Moves in the game:", moves)

# Function to determine the opening
def determine_opening(moves, openings):
    for opening_name, opening_moves in openings.items():
        if moves[:len(opening_moves)] == opening_moves:
            return opening_name
    return "Unknown Opening"

# Determine the opening
opening_name = determine_opening(moves, openings)
print("The opening is:", opening_name)
# Out:
# PGN String: 1. d4 e6 2. Bf4 d5 3. Nf3 Bd6 4. g3 Nf6
# Moves in the game: ['d4', 'e6', 'Bf4', 'd5', 'Nf3', 'Bd6', 'g3', 'Nf6']
# The opening is: Queen's Pawn Game

# %%
import pandas as pd
import chess.pgn
import io

# Sample DataFrame
data = {
    'pgn': [
        "1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+"
    ]
}

df = pd.DataFrame(data)

# Read the PGN string from the first cell of the 'pgn' column
pgn_string = df.loc[0, 'pgn']
print("PGN String:", pgn_string)

# Define an openings database
openings = {
    "Queen's Pawn Game": ["d4", "e6", "Bf4", "d5", "Nf3", "Bd6", "g3", "Nf6"],
    # Add more openings as needed
}

# Function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Extract the moves
moves = extract_moves_from_pgn(pgn_string)
print("Moves in the game:", moves)

# Function to determine the opening
def determine_opening(moves, openings):
    for opening_name, opening_moves in openings.items():
        if moves[:len(opening_moves)] == opening_moves:
            return opening_name
    return "Unknown Opening"

# Determine the opening
opening_name = determine_opening(moves, openings)
print("The opening is:", opening_name)
# Out:
# PGN String: 1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+
# Moves in the game: ['e4', 'e5', 'f4', 'exf4', 'Nf3', 'g5', 'Bc4', 'g4', 'O-O', 'gxf3', 'Qxf3', 'Qf6', 'e5', 'Qxe5', 'Bxf7+']
# The opening is: Unknown Opening

# %%
moves
# Out:
# ['e4',
#  'e5',
#  'f4',
#  'exf4',
#  'Nf3',
#  'g5',
#  'Bc4',
#  'g4',
#  'O-O',
#  'gxf3',
#  'Qxf3',
#  'Qf6',
#  'e5',
#  'Qxe5',
#  'Bxf7+']

# %%
import pandas as pd
import chess.pgn
import io

# Sample DataFrame for demonstration
data = {
    'pgn': [
        "1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+"
    ]
}

df = pd.DataFrame(data)

# Read the PGN string from the first cell of the 'pgn' column
pgn_string = df.loc[0, 'pgn']
print("PGN String:", pgn_string)

# Sample DataFrame `a_df` containing chess openings database
a_df = pd.DataFrame({
    'chess_database': [
        {"Queen's Pawn Game": ["d4", "e6", "Bf4", "d5", "Nf3", "Bd6", "g3", "Nf6"]},
        {"Sicilian Defense": ["e4", "c5"]},
        {"French Defense": ["e4", "e6"]},
        # Add more openings as needed
    ]
})

# Function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Extract the moves
moves = extract_moves_from_pgn(pgn_string)
print("Moves in the game:", moves)

# Function to determine the opening
def determine_opening(moves, openings):
    for index, row in openings.iterrows():
        for opening_name, opening_moves in row['chess_database'].items():
            if moves[:len(opening_moves)] == opening_moves:
                return opening_name
    return "Unknown Opening"

# Determine the opening using `a_df`
opening_name = determine_opening(moves, a_df)
print("The opening is:", opening_name)
# Out:
# PGN String: 1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+
# Moves in the game: ['e4', 'e5', 'f4', 'exf4', 'Nf3', 'g5', 'Bc4', 'g4', 'O-O', 'gxf3', 'Qxf3', 'Qf6', 'e5', 'Qxe5', 'Bxf7+']
# The opening is: Unknown Opening

# %%
# Out:
#                                       chess_database
# 0  {'Queen's Pawn Game': ['d4', 'e6', 'Bf4', 'd5'...
# 1                 {'Sicilian Defense': ['e4', 'c5']}
# 2                   {'French Defense': ['e4', 'e6']}

# %%
import pandas as pd
import chess.pgn
import io

# Sample DataFrame for demonstration
data = {
    'pgn': [
        "1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+"
    ]
}

df = pd.DataFrame(data)

# Read the PGN string from the first cell of the 'pgn' column
pgn_string = df.loc[0, 'pgn']
print("PGN String:", pgn_string)

# Sample DataFrame `a_df` containing chess openings database
data_openings = {
    'opening_name': ["Queen's Pawn Game", "Sicilian Defense", "French Defense"],
    'opening_moves': [
        ["d4", "e6", "Bf4", "d5", "Nf3", "Bd6", "g3", "Nf6"],
        ["e4", "c5"],
        ["e4", "e5"]
    ]
}

a_df = pd.DataFrame(data_openings)

# Function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Extract the moves
moves = extract_moves_from_pgn(pgn_string)
print("Moves in the game:", moves)

# Function to determine the opening
def determine_opening(moves, openings):
    for index, row in openings.iterrows():
        opening_name = row['opening_name']
        opening_moves = row['opening_moves']
        if moves[:len(opening_moves)] == opening_moves:
            return opening_name
    return "Unknown Opening"

# Determine the opening using `a_df`
opening_name = determine_opening(moves, a_df)
print("The opening is:", opening_name)
# Out:
# PGN String: 1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+
# Moves in the game: ['e4', 'e5', 'f4', 'exf4', 'Nf3', 'g5', 'Bc4', 'g4', 'O-O', 'gxf3', 'Qxf3', 'Qf6', 'e5', 'Qxe5', 'Bxf7+']
# The opening is: French Defense

# %%
import pandas as pd
import chess.pgn
import io

# Define the function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    if not isinstance(pgn_string, str):
        return []
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Read the TSV files into DataFrames
a_df = pd.read_csv('chess-openings/a.tsv', sep='\t')
b_df = pd.read_csv('chess-openings/b.tsv', sep='\t')
c_df = pd.read_csv('chess-openings/c.tsv', sep='\t')
d_df = pd.read_csv('chess-openings/d.tsv', sep='\t')
e_df = pd.read_csv('chess-openings/e.tsv', sep='\t')


# Combine the DataFrames
combined_df = pd.concat([a_df, b_df, c_df, d_df, e_df], ignore_index=True)

# Create a new column for the extracted moves
chess_moves = []

# Iterate over the rows of the combined DataFrame
for index, row in combined_df.iterrows():
    pgn_string = row['pgn']
    moves = extract_moves_from_pgn(pgn_string)
    chess_moves.append(moves)

# Add the new column to the DataFrame
combined_df['opening_moves'] = chess_moves

# Display the combined DataFrame to verify the new column
print(combined_df.head())
# Out:
#    eco                                     name  \
# 0  A00                             Amar Opening
# 1  A00               Amar Opening: Paris Gambit
# 2  A00  Amar Opening: Paris Gambit, Gent Gambit
# 3  A00                         Amsterdam Attack
# 4  A00                      Anderssen's Opening
#
#                                                  pgn  \
# 0                                             1. Nh3
# 1                           1. Nh3 d5 2. g3 e5 3. f4
# 2  1. Nh3 d5 2. g3 e5 3. f4 Bxh3 4. Bxh3 exf4 5. ...
# 3             1. e3 e5 2. c4 d6 3. Nc3 Nc6 4. b3 Nf6
# 4                                              1. a3
#
#                                        opening_moves
# 0                                              [Nh3]
# 1                              [Nh3, d5, g3, e5, f4]
# 2  [Nh3, d5, g3, e5, f4, Bxh3, Bxh3, exf4, O-O, f...
# 3                [e3, e5, c4, d6, Nc3, Nc6, b3, Nf6]
# 4                                               [a3]

# %%
import pandas as pd
import chess.pgn
import io

# Sample DataFrame for demonstration
data = {
    'pgn': [
        "1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+"
    ]
}

df = pd.DataFrame(data)

# Read the PGN string from the first cell of the 'pgn' column
pgn_string = df.loc[0, 'pgn']
print("PGN String:", pgn_string)

# Sample DataFrame `a_df` containing chess openings database
# data_openings = {
#     'opening_name': ["Queen's Pawn Game", "Sicilian Defense", "French Defense"],
#     'opening_moves': [
#         ["d4", "e6", "Bf4", "d5", "Nf3", "Bd6", "g3", "Nf6"],
#         ["e4", "c5"],
#         ["e4", "e5"]
#     ]
# }

# a_df = pd.DataFrame(data_openings)


# Display the first few rows of the DataFrame
print(df.head())
# Function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Extract the moves
moves = extract_moves_from_pgn(pgn_string)
print("Moves in the game:", moves)

# Function to determine the opening
def determine_opening(moves, openings):
    for index, row in openings.iterrows():
        opening_name = row['name']
        opening_moves = row['opening_moves']
        if moves[:len(opening_moves)] == opening_moves:
            return opening_name
    return "Unknown Opening"

# Determine the opening using `a_df`
opening_name = determine_opening(moves, combined_df)
print("The opening is:", opening_name)
# Out:
# PGN String: 1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O gxf3 6. Qxf3 Qf6 7. e5 Qxe5 8. Bxf7+
#                                                  pgn
# 0  1. e4 e5 2. f4 exf4 3. Nf3 g5 4. Bc4 g4 5. O-O...
# Moves in the game: ['e4', 'e5', 'f4', 'exf4', 'Nf3', 'g5', 'Bc4', 'g4', 'O-O', 'gxf3', 'Qxf3', 'Qf6', 'e5', 'Qxe5', 'Bxf7+']
# The opening is: King's Pawn Game

# %%
a_df
# Out:
#       eco                                               name  \
# 0     A00                                       Amar Opening
# 1     A00                         Amar Opening: Paris Gambit
# 2     A00            Amar Opening: Paris Gambit, Gent Gambit
# 3     A00                                   Amsterdam Attack
# 4     A00                                Anderssen's Opening
# ...   ...                                                ...
# 3459  E98  King's Indian Defense: Orthodox Variation, Cla...
# 3460  E98  King's Indian Defense: Orthodox Variation, Cla...
# 3461  E98  King's Indian Defense: Orthodox Variation, Cla...
# 3462  E99  King's Indian Defense: Orthodox Variation, Cla...
# 3463  E99  King's Indian Defense: Orthodox Variation, Cla...
#
#                                                     pgn  \
# 0                                                1. Nh3
# 1                              1. Nh3 d5 2. g3 e5 3. f4
# 2     1. Nh3 d5 2. g3 e5 3. f4 Bxh3 4. Bxh3 exf4 5. ...
# ...

# %%
import pandas as pd
import chess.pgn
import io

# Sample DataFrame for demonstration
data = {
    'pgn': [
        "1. e4 e6 2. Nf3 d5 3. e5 c5 4. d4 Nc6 5. c3 cxd4 6. cxd4 Qa5+ 7. Bd2 Bb4 8. Nc3Qb6 9. Na4 Bxd2+ 10. Nxd2 Qb4 11. a3 Qe7 12. Bb5 Qh4 13. Qc1 Bd7 14. g3 Qxd4 15.Qc2 Qxe5+ 16. Be2 Nf6 17. O-O-O O-O 18. Nf3 Qd6 19. Nc5 a6 (19... Rfc8 20. Nxb7Qb8 21. Nc5 Na5 22. Kb1 Nc4 23. Nxd7 Nxa3+ 24. Ka2 Nxc2 25. Nxb8) 20. Nxb7 Qc721. Nc5 a5 22. Na6 Qb6 23. Nc5 Rfe8 24. Nxd7 Nxd7 25. Rhe1 Rac8 26. Kb1 Nd4 27.Qd3 Rb8 28. Nxd4 Qxb2# 0-1 {take advantage of relative pins move a rook where the queen is}"
    ]
}

df = pd.DataFrame(data)

# Read the PGN string from the first cell of the 'pgn' column
pgn_string = df.loc[0, 'pgn']
print("PGN String:", pgn_string)

# Sample DataFrame `a_df` containing chess openings database
# data_openings = {
#     'opening_name': ["Queen's Pawn Game", "Sicilian Defense", "French Defense"],
#     'opening_moves': [
#         ["d4", "e6", "Bf4", "d5", "Nf3", "Bd6", "g3", "Nf6"],
#         ["e4", "c5"],
#         ["e4", "e5"]
#     ]
# }

# a_df = pd.DataFrame(data_openings)


# Display the first few rows of the DataFrame
print(df.head())
# Function to extract moves from PGN string
def extract_moves_from_pgn(pgn_string):
    pgn_io = io.StringIO(pgn_string)
    game = chess.pgn.read_game(pgn_io)
    board = game.board()
    moves = []
    for move in game.mainline_moves():
        moves.append(board.san(move))
        board.push(move)
    return moves

# Extract the moves
moves = extract_moves_from_pgn(pgn_string)
print("Moves in the game:", moves)

# Updated function to determine the opening
def determine_opening(moves, openings):
    best_match = "Unknown Opening"
    max_matched_moves = 0

    for index, row in openings.iterrows():
        opening_name = row['name']
        opening_moves = row['opening_moves']
        matched_moves = 0

        # Count matched moves
        for i in range(min(len(moves), len(opening_moves))):
            if moves[i] == opening_moves[i]:
                matched_moves += 1
            else:
                break

        # Update best match if this opening matches more moves
        if matched_moves > max_matched_moves:
            best_match = opening_name
            max_matched_moves = matched_moves

    return best_match

# Determine the opening using `a_df`
opening_name = determine_opening(moves, combined_df)
print("The opening is:", opening_name)
# Out:
# illegal san: 'Nc3Q' in r1b1k1nr/pp3ppp/2n1p3/q2pP3/1b1P4/5N2/PP1B1PPP/RN1QKB1R w KQkq - 3 8 while parsing <Game at 0x16144b4d0 ('?' vs. '?', '????.??.??' at '?')>
# PGN String: 1. e4 e6 2. Nf3 d5 3. e5 c5 4. d4 Nc6 5. c3 cxd4 6. cxd4 Qa5+ 7. Bd2 Bb4 8. Nc3Qb6 9. Na4 Bxd2+ 10. Nxd2 Qb4 11. a3 Qe7 12. Bb5 Qh4 13. Qc1 Bd7 14. g3 Qxd4 15.Qc2 Qxe5+ 16. Be2 Nf6 17. O-O-O O-O 18. Nf3 Qd6 19. Nc5 a6 (19... Rfc8 20. Nxb7Qb8 21. Nc5 Na5 22. Kb1 Nc4 23. Nxd7 Nxa3+ 24. Ka2 Nxc2 25. Nxb8) 20. Nxb7 Qc721. Nc5 a5 22. Na6 Qb6 23. Nc5 Rfe8 24. Nxd7 Nxd7 25. Rhe1 Rac8 26. Kb1 Nd4 27.Qd3 Rb8 28. Nxd4 Qxb2# 0-1 {take advantage of relative pins move a rook where the queen is}
#                                                  pgn
# 0  1. e4 e6 2. Nf3 d5 3. e5 c5 4. d4 Nc6 5. c3 cx...
# Moves in the game: ['e4', 'e6', 'Nf3', 'd5', 'e5', 'c5', 'd4', 'Nc6', 'c3', 'cxd4', 'cxd4', 'Qa5+', 'Bd2', 'Bb4']
# The opening is: French Defense: Wing Gambit
